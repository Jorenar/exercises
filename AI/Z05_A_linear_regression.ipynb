# %% [markdown]
# # Regresja liniowa

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k');
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.
# My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
M1 = np.vstack( (np.ones_like(x), x) ).T
p1 = np.linalg.lstsq(M1, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_1 = lambda x: p1[0][1] * x +p1[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_1(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_2 = lambda x: p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_2(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M3 = np.vstack((np.ones_like(x), x, x**2, x**3)).T
p3 = np.linalg.lstsq(M3, y, rcond=None)

f_lr_3 = lambda x: p3[0][3]*pow(x,3) + p3[0][2]*pow(x,2) + p3[0][1] * x + p3[0][0] 

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_3(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M4 = np.vstack((np.ones_like(x), x, x**2, x**3, x**4)).T
p4 = np.linalg.lstsq(M4, y, rcond=None)

f_lr_4 = lambda x: p4[0][4]*pow(x,4) + p4[0][3]*pow(x,3) + p4[0][2]*pow(x,2) + p4[0][1] * x + p4[0][0] 

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_4(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + a_5 \cdot x^5 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M5 = np.vstack((np.ones_like(x), x, x**2, x**3,x**4,x**5)).T
p5 = np.linalg.lstsq(M5, y, rcond=None)
f_lr_5 = lambda x:p5[0][5]*pow(x,5)+ p5[0][4]*pow(x,4)+p5[0][3]*pow(x,3)+p5[0][2]*pow(x,2) + p5[0][1] * x + p5[0][0]
x_f_lr = np.linspace(0.,3,200)
y_f_lr = f_lr_5(x_tr)

plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.

# %%
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])

x_f_lr = np.linspace(0.,3,200)

plt.plot(x_f_lr, f_lr_1(x_tr), 'r');
plt.plot(x_f_lr, f_lr_2(x_tr), 'g');
plt.plot(x_f_lr, f_lr_3(x_tr), 'b');
plt.plot(x_f_lr, f_lr_4(x_tr), 'c');
plt.plot(x_f_lr, f_lr_5(x_tr), 'm');

plt.plot(x, y, 'ok', ms=10);

# %% [markdown]
# ### Która z krzywych jest najlepsza?

# %% [markdown]
# Najlepsza jest czwarta krzywa (AIC = -37.3975)

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
import statsmodels.api as sm
Res1 = sm.OLS(y, M1).fit()
Res2 = sm.OLS(y, M2).fit()

# %%
print(Res1.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.489
# Dependent Variable: y                AIC:                646.5467
# Date:               2022-04-01 08:37 BIC:                651.7571
# No. Observations:   100              Log-Likelihood:     -321.27
# Df Model:           1                F-statistic:        95.72
# Df Residuals:       98               Prob (F-statistic): 3.57e-16
# R-squared:          0.494            Scale:              36.885
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# -------------------------------------------------------------------
# const     -4.1690     1.2853   -3.2435   0.0016   -6.7197   -1.6183
# x1         7.1553     0.7313    9.7837   0.0000    5.7040    8.6066
# -----------------------------------------------------------------
# Omnibus:              25.758       Durbin-Watson:          1.978
# Prob(Omnibus):        0.000        Jarque-Bera (JB):       37.451
# Skew:                 1.203        Prob(JB):               0.000
# Kurtosis:             4.788        Condition No.:          5
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.808
# Dependent Variable: y                AIC:                549.8532
# Date:               2022-04-01 08:37 BIC:                557.6688
# No. Observations:   100              Log-Likelihood:     -271.93
# Df Model:           2                F-statistic:        208.7
# Df Residuals:       97               Prob (F-statistic): 7.22e-36
# R-squared:          0.811            Scale:              13.889
# ------------------------------------------------------------------
#             Coef.    Std.Err.     t     P>|t|    [0.025    0.975]
# ------------------------------------------------------------------
# const        8.8878    1.2909   6.8850  0.0000    6.3258   11.4499
# x1         -16.2391    1.8852  -8.6141  0.0000  -19.9807  -12.4975
# x2           7.5044    0.5873  12.7770  0.0000    6.3387    8.6701
# -----------------------------------------------------------------
# Omnibus:              2.266        Durbin-Watson:           2.108
# Prob(Omnibus):        0.322        Jarque-Bera (JB):        2.154
# Skew:                 0.280        Prob(JB):                0.341
# Kurtosis:             2.550        Condition No.:           28
# =================================================================

# %%
Res3 = sm.OLS(y, M3).fit()
Res4 = sm.OLS(y, M4).fit()
Res5 = sm.OLS(y, M5).fit()

print(Res3.summary2())
print("\n")
print(Res4.summary2())
print("\n")
print(Res5.summary2())
# Out:
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.992
# Dependent Variable: y                AIC:                236.4067
# Date:               2022-04-01 08:37 BIC:                246.8273
# No. Observations:   100              Log-Likelihood:     -114.20
# Df Model:           3                F-statistic:        3946.
# Df Residuals:       96               Prob (F-statistic): 2.27e-100
# R-squared:          0.992            Scale:              0.59870
# -------------------------------------------------------------------
#             Coef.    Std.Err.     t      P>|t|    [0.025    0.975]
# -------------------------------------------------------------------
# const       -4.5793    0.3950  -11.5934  0.0000   -5.3633   -3.7952
# x1          28.5520    1.0414   27.4175  0.0000   26.4849   30.6191
# x2         -27.3035    0.7598  -35.9357  0.0000  -28.8117  -25.7954
# x3           7.4419    0.1603   46.4143  0.0000    7.1237    7.7602
# ------------------------------------------------------------------
# Omnibus:               6.426        Durbin-Watson:           2.077
# Prob(Omnibus):         0.040        Jarque-Bera (JB):        6.538
# Skew:                  0.593        Prob(JB):                0.038
# Kurtosis:              2.599        Condition No.:           195
# ==================================================================
#
#
#
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -37.3975
# Date:               2022-04-01 08:37 BIC:                -24.3717
# No. Observations:   100              Log-Likelihood:     23.699
# Df Model:           4                F-statistic:        4.654e+04
# Df Residuals:       95               Prob (F-statistic): 1.99e-155
# R-squared:          0.999            Scale:              0.038367
# --------------------------------------------------------------------
#            Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const     -0.9377     0.1395    -6.7236   0.0000   -1.2146   -0.6608
# x1         9.5482     0.5718    16.6999   0.0000    8.4131   10.6832
# x2        -1.3653     0.7187    -1.8997   0.0605   -2.7921    0.0615
# x3        -5.3255     0.3433   -15.5144   0.0000   -6.0070   -4.6440
# x4         2.0551     0.0549    37.4573   0.0000    1.9462    2.1640
# ------------------------------------------------------------------
# Omnibus:              1.291         Durbin-Watson:           2.364
# Prob(Omnibus):        0.524         Jarque-Bera (JB):        1.172
# Skew:                 -0.263        Prob(JB):                0.556
# Kurtosis:             2.926         Condition No.:           1492
# ==================================================================
# * The condition number is large (1e+03). This might indicate
# strong multicollinearity or other numerical problems.
#
#
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -37.3661
# Date:               2022-04-01 08:37 BIC:                -21.7351
# No. Observations:   100              Log-Likelihood:     24.683
# Df Model:           5                F-statistic:        3.757e+04
# Df Residuals:       94               Prob (F-statistic): 1.82e-153
# R-squared:          0.999            Scale:              0.038019
# --------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025     0.975]
# --------------------------------------------------------------------
# const     -0.7474     0.1966   -3.8012   0.0003    -1.1378   -0.3570
# x1         8.1734     1.1555    7.0733   0.0000     5.8791   10.4677
# x2         1.4282     2.1651    0.6596   0.5111    -2.8706    5.7269
# x3        -7.6194     1.7125   -4.4494   0.0000   -11.0195   -4.2193
# x4         2.8710     0.5993    4.7903   0.0000     1.6810    4.0610
# x5        -0.1046     0.0765   -1.3670   0.1749    -0.2566    0.0473
# ------------------------------------------------------------------
# Omnibus:              0.979         Durbin-Watson:           2.309
# Prob(Omnibus):        0.613         Jarque-Bera (JB):        1.081
# Skew:                 -0.209        Prob(JB):                0.582
# Kurtosis:             2.708         Condition No.:           12634
# ==================================================================
# * The condition number is large (1e+04). This might indicate
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Zadanie
# Analogiczne wyniki możemy uzyskać za pomocą prostego kodu.

# %%
import statsmodels.formula.api as smf
# Turn the data into a pandas DataFrame, so that we
# can address them in the formulas with their name
df = pd.DataFrame({'x':x, 'y':y})

# Fit the models, and show the results
Res1F = smf.ols('y~x', df).fit()
Res2F = smf.ols('y ~ x+I(x**2)', df).fit()

# %%
print(Res1F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2F.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.494
# Model:                            OLS   Adj. R-squared:                  0.489
# Method:                 Least Squares   F-statistic:                     95.72
# Date:                Fri, 01 Apr 2022   Prob (F-statistic):           3.57e-16
# Time:                        08:37:54   Log-Likelihood:                -321.27
# No. Observations:                 100   AIC:                             646.5
# Df Residuals:                      98   BIC:                             651.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -4.1690      1.285     -3.244      0.002      -6.720      -1.618
# x              7.1553      0.731      9.784      0.000       5.704       8.607
# ==============================================================================
# Omnibus:                       25.758   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.451
# Skew:                           1.203   Prob(JB):                     7.37e-09
# Kurtosis:                       4.788   Cond. No.                         4.71
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.811
# Model:                            OLS   Adj. R-squared:                  0.808
# Method:                 Least Squares   F-statistic:                     208.7
# Date:                Fri, 01 Apr 2022   Prob (F-statistic):           7.22e-36
# Time:                        08:37:54   Log-Likelihood:                -271.93
# No. Observations:                 100   AIC:                             549.9
# Df Residuals:                      97   BIC:                             557.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      8.8878      1.291      6.885      0.000       6.326      11.450
# x            -16.2391      1.885     -8.614      0.000     -19.981     -12.498
# I(x ** 2)      7.5044      0.587     12.777      0.000       6.339       8.670
# ==============================================================================
# Omnibus:                        2.266   Durbin-Watson:                   2.108
# Prob(Omnibus):                  0.322   Jarque-Bera (JB):                2.154
# Skew:                           0.280   Prob(JB):                        0.341
# Kurtosis:                       2.550   Cond. No.                         27.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
Res3F = smf.ols('y ~ x+I(x**2)+I(x**3)', df).fit()
Res4F = smf.ols('y ~ x+I(x**2)+I(x**3)+I(x**4)', df).fit()
Res5F = smf.ols('y ~ x+I(x**2)+I(x**3)+I(x**4)+I(x**5)', df).fit()

print(Res3F.summary())
print("\n\n\n")
print(Res4F.summary())
print("\n\n\n")
print(Res5F.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                     3946.
# Date:                Fri, 01 Apr 2022   Prob (F-statistic):          2.27e-100
# Time:                        08:37:54   Log-Likelihood:                -114.20
# No. Observations:                 100   AIC:                             236.4
# Df Residuals:                      96   BIC:                             246.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -4.5793      0.395    -11.593      0.000      -5.363      -3.795
# x             28.5520      1.041     27.417      0.000      26.485      30.619
# I(x ** 2)    -27.3035      0.760    -35.936      0.000     -28.812     -25.795
# I(x ** 3)      7.4419      0.160     46.414      0.000       7.124       7.760
# ==============================================================================
# Omnibus:                        6.426   Durbin-Watson:                   2.077
# Prob(Omnibus):                  0.040   Jarque-Bera (JB):                6.538
# Skew:                           0.593   Prob(JB):                       0.0380
# Kurtosis:                       2.599   Cond. No.                         195.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 4.654e+04
# Date:                Fri, 01 Apr 2022   Prob (F-statistic):          1.99e-155
# Time:                        08:37:54   Log-Likelihood:                 23.699
# No. Observations:                 100   AIC:                            -37.40
# Df Residuals:                      95   BIC:                            -24.37
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.9377      0.139     -6.724      0.000      -1.215      -0.661
# x              9.5482      0.572     16.700      0.000       8.413      10.683
# I(x ** 2)     -1.3653      0.719     -1.900      0.061      -2.792       0.061
# I(x ** 3)     -5.3255      0.343    -15.514      0.000      -6.007      -4.644
# I(x ** 4)      2.0551      0.055     37.457      0.000       1.946       2.164
# ==============================================================================
# Omnibus:                        1.291   Durbin-Watson:                   2.364
# Prob(Omnibus):                  0.524   Jarque-Bera (JB):                1.172
# Skew:                          -0.263   Prob(JB):                        0.556
# Kurtosis:                       2.926   Cond. No.                     1.49e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.49e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 3.757e+04
# Date:                Fri, 01 Apr 2022   Prob (F-statistic):          1.82e-153
# Time:                        08:37:54   Log-Likelihood:                 24.683
# No. Observations:                 100   AIC:                            -37.37
# Df Residuals:                      94   BIC:                            -21.74
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.7474      0.197     -3.801      0.000      -1.138      -0.357
# x              8.1734      1.156      7.073      0.000       5.879      10.468
# I(x ** 2)      1.4282      2.165      0.660      0.511      -2.871       5.727
# I(x ** 3)     -7.6194      1.712     -4.449      0.000     -11.020      -4.219
# I(x ** 4)      2.8710      0.599      4.790      0.000       1.681       4.061
# I(x ** 5)     -0.1046      0.077     -1.367      0.175      -0.257       0.047
# ==============================================================================
# Omnibus:                        0.979   Durbin-Watson:                   2.309
# Prob(Omnibus):                  0.613   Jarque-Bera (JB):                1.081
# Skew:                          -0.209   Prob(JB):                        0.582
# Kurtosis:                       2.708   Cond. No.                     1.26e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.26e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
